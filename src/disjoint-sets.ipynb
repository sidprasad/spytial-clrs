# %%
# %pip install spytial-diagramming
from spytial import *
from spytial.annotations import *
# Out:
# Requirement already satisfied: spytial-diagramming in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: jinja2>=3.0.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (3.1.6)
# Requirement already satisfied: pyyaml>=6.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (6.0.3)
# Requirement already satisfied: ipython>=8.0.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (9.5.0)
# Requirement already satisfied: decorator in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (2.19.2)
# Requirement already satisfied: stack_data in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.0.0->spytial-diagramming) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from jedi>=0.16->ipython>=8.0.0->spytial-diagramming) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from jinja2>=3.0.0->spytial-diagramming) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from pexpect>4.3->ipython>=8.0.0->spytial-diagramming) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (0.2.3)
# Requirement already satisfied: jinja2>=3.0.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (3.1.6)
# Requirement already satisfied: pyyaml>=6.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (6.0.3)
# Requirement already satisfied: ipython>=8.0.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from spytial-diagramming) (9.5.0)
# Requirement already satisfied: decorator in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (2.19.2)
# Requirement already satisfied: stack_data in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from ipython>=8.0.0->spytial-diagramming) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.0.0->spytial-diagramming) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from jedi>=0.16->ipython>=8.0.0->spytial-diagramming) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from jinja2>=3.0.0->spytial-diagramming) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from pexpect>4.3->ipython>=8.0.0->spytial-diagramming) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/siddharthaprasad/miniforge3/envs/spytial/lib/python3.11/site-packages (from stack_data->ipython>=8.0.0->spytial-diagramming) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup for performance metrics
import random
# Set this to True to run performance tests
RUN_PERF = False

perf_base = "spytial_perf"
def get_perf_path(structure, size):
    return perf_base + "_" + structure + "_" + f"{size}.json"
PI = 20
SIZES = [5, 10, 25, 50]

# %% [markdown]
# # Disjoint Sets
#
# There are multiple possible visualizations here, depending on how much of the mechanization you might want.
#
# - Just as sets of objects: Set the `VIEW` variable to `SET_ONLY` and run all.
# - Just as a forest (as in CLRS): Set the `VIEW` variable to `FOREST_ONLY`
# - Or as a combination of both: Set the `VIEW` variable to `FOREST+SET`

# %%
VIEW = "FOREST+SET"
#VIEW = "FOREST_ONLY"
#VIEW = "SET_ONLY"

# %%
@attribute(field="key")
@attribute(field="rank")
@hideAtom(selector="int + str")
@apply_if(
    VIEW == "FOREST_ONLY",
    orientation(selector='(parent - iden) & (DSUNode->DSUNode)', directions=['above']),
    orientation(selector='{ x, y : DSUNode | (x != y) and (@num:(x.rank) < @num:(y.rank)) }', directions=['above']),
)

@apply_if(
    VIEW == "SET_ONLY",
    group(selector='~parent', name='set'),
    hideField(field='parent'),
)
@apply_if(
    VIEW == "FOREST+SET",
    orientation(selector='(parent - iden) & (DSUNode->DSUNode)', directions=['above']),
    group(selector='^(~parent)', name='set'),
    orientation(selector='{ x, y : DSUNode | (x != y) and (@num:(x.rank) < @num:(y.rank)) }', directions=['above']),
)
class DSUNode:
    def __init__(self, key):
        self.key = key
        self.parent = self   # MAKE-SET
        self.rank = 0        # tree rank (upper bound on height)


class DisjointSet:
    def make_set(self, key):
        return DSUNode(key)

    # FIND-SET with path compression
    def find_set(self, x: DSUNode) -> DSUNode:
        if x.parent is not x:
            x.parent = self.find_set(x.parent)
        return x.parent

    # UNION by rank
    def union(self, x: DSUNode, y: DSUNode) -> DSUNode:
        return self._link(self.find_set(x), self.find_set(y))

    def _link(self, x_root: DSUNode, y_root: DSUNode) -> DSUNode:
        if x_root is y_root:
            return x_root
        if x_root.rank > y_root.rank:
            y_root.parent = x_root
            return x_root
        else:
            x_root.parent = y_root
            if x_root.rank == y_root.rank:
                y_root.rank += 1
            return y_root

# %% [markdown]
# CLRS: Fig 21.4 (Page 569)
#
# ![disjoint](./img/disjoint-set-forest.png)

# %%
# Create a DisjointSet instance and some DSU nodes, perform unions, and render a diagram.
ds = DisjointSet()

# MAKE-SET for elements
f = ds.make_set("f")
d = ds.make_set("d")
g = ds.make_set("c")

b = ds.make_set("b")
h = ds.make_set("h")
c = ds.make_set("c")
e = ds.make_set("e")  # will remain a separate set


ds.union(h, b)
ds.union(c, h)
ds.union(c,e)

ds.union(d,g)
ds.union(f, d)


to_diagram = hideAtom(selector="list")([f,d,g,b,h,c,e])
diagram(to_diagram)

ds.union(f, c)  
diagram(to_diagram)
# Out:
#                 <div style="border: 2px solid #007acc; border-radius: 8px; overflow: hidden;">
#                     <iframe
#                         src="data:text/html;base64,..."
#                         width="100%"
#                         height="450px"
#                         frameborder="0"
#                         style="display: block;">
#                     </iframe>
#                 </div>
#                 <div style="border: 2px solid #007acc; border-radius: 8px; overflow: hidden;">
#                     <iframe
#                         src="data:text/html;base64,..."
#                         width="100%"
#                         height="450px"
#                         frameborder="0"
#                         style="display: block;">
#                     </iframe>
#                 </div>

# %% [markdown]
# ## Performance

# %%
if RUN_PERF:
    STRUCTURE = "disjoint_set"
    for size in SIZES:
        # Create disjoint set with size elements
        ds = DisjointSet()
        elements = [ds.make_set(i) for i in range(size)]
        
        # Perform some random unions
        for _ in range(size // 2):
            i, j = random.sample(range(size), 2)
            ds.union(elements[i], elements[j])
        
        to_diagram = hideAtom(selector="list")(elements)
        diagram(to_diagram, method="browser", perf_path=get_perf_path(STRUCTURE, size), perf_iterations=PI, timeout=500, headless=True)
else:
    print("Performance testing skipped. Set RUN_PERF = True to enable.")
# Out:
# Performance testing skipped. Set RUN_PERF = True to enable.
