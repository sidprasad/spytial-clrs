# %%
import sys
from pathlib import Path

# Add the parent directory to the Python path
sys.path.append(str(Path().resolve().parent))

from spytial import *
from spytial.annotations import *
from spytial.annotations import flag

# %%
# Setup for performance metrics - create nested directories
import random
from time import sleep

# Set this to True to run performance tests
RUN_PERF = False

perf_base = "spytial_perf"
def get_perf_path(structure, size):
    return perf_base + "_" + structure + "_" + f"{size}.json"
PI = 20
SIZES = [5, 10, 25, 50]

# %% [markdown]
# # Singly Linked List

# %%
# Conception, next in a continuous line.
@orientation(selector='next', directions=['directlyRight'])
@orientation(selector='data', directions=['below'])
class SinglyNode:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next = next_node

# %%
def buildSinglyLinkedList(elements):
    head = None
    for element in reversed(elements):
        head = SinglyNode(element, head)
    return head


xs = buildSinglyLinkedList([7, 3, 1, 9, 2])
diagram(xs)
# Out:
#                 <div style="border: 2px solid #007acc; border-radius: 8px; overflow: hidden;">
#                     <iframe
#                         src="data:text/html;base64,..."
#                         width="100%"
#                         height="450px"
#                         frameborder="0"
#                         style="display: block;">
#                     </iframe>
#                 </div>

# %% [markdown]
# ## Performance

# %%
if RUN_PERF:
    STRUCTURE = "singly_linked_list"
    for size in SIZES:
        elements = random.sample(range(1, 1000), size)
        sll = buildSinglyLinkedList(elements)
        
        print(f"{STRUCTURE}({size} nodes): Rendering with perf_iterations={PI}...")
        diagram(sll, method="browser", perf_path=get_perf_path(STRUCTURE, size), perf_iterations=PI, headless=True)
        sleep(2)
else:
    print("Performance testing skipped. Set RUN_PERF = True to enable.")
# Out:
# singly_linked_list(5 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 4.11ms avg
#   Render Layout: 47.32ms avg
#   Total Time: 51.81ms avg
#   Metrics saved to: spytial_perf_singly_linked_list_5.json
# singly_linked_list(10 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 5.10ms avg
#   Render Layout: 89.14ms avg
#   Total Time: 94.78ms avg
#   Metrics saved to: spytial_perf_singly_linked_list_10.json
# singly_linked_list(25 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 5.70ms avg
#   Render Layout: 192.17ms avg
#   Total Time: 198.60ms avg
#   Metrics saved to: spytial_perf_singly_linked_list_25.json
# singly_linked_list(50 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.5s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 8.77ms avg
#   Render Layout: 348.46ms avg
#   Total Time: 358.42ms avg
#   Metrics saved to: spytial_perf_singly_linked_list_50.json

# %% [markdown]
# # Doubly Linked List

# %%
# Conception, next and prev laid out in opposite directions.
@orientation(selector='next & (DoublyNode->DoublyNode)', directions=['directlyRight'])
@orientation(selector='prev & (DoublyNode->DoublyNode)', directions=['directlyLeft'])
@hideAtom(selector="NoneType + int")
@orientation(directions=["below"], selector='data & (DoublyNode->str)') #{x: DoublyNode, d : str | x.data = d}')
@attribute(field="data")
@atomColor(selector='{x : DoublyNode | x.prev in NoneType}', value='black')
class DoublyNode:
    def __init__(self, data, next_node=None, prev_node=None):
        self.data = data
        self.next = next_node
        self.prev = prev_node

# %% [markdown]
# ![dll](img/doubly-linked-list.png)

# %%
def buildDoublyLinkedList(elements):
    head = None
    prev_node = None
    for element in elements:
        new_node = DoublyNode(element, None, prev_node)
        if prev_node is not None:
            prev_node.next = new_node
        else:
            head = new_node
        prev_node = new_node
    return head

ys = buildDoublyLinkedList([25, 9, 16, 4, 1])
diagram(ys)
# Out:
#                 <div style="border: 2px solid #007acc; border-radius: 8px; overflow: hidden;">
#                     <iframe
#                         src="data:text/html;base64,..."
#                         width="100%"
#                         height="450px"
#                         frameborder="0"
#                         style="display: block;">
#                     </iframe>
#                 </div>

# %% [markdown]
# ## Performance

# %%
if RUN_PERF:
    STRUCTURE = "doubly_linked_list"
    for size in SIZES:
        elements = random.sample(range(1, 1000), size)
        dll = buildDoublyLinkedList(elements)
        
        print(f"{STRUCTURE}({size} nodes): Rendering with perf_iterations={PI}...")
        diagram(dll, method="browser", perf_path=get_perf_path(STRUCTURE, size), perf_iterations=PI, headless=True)
else:
    print("Performance testing skipped. Set RUN_PERF = True to enable.")
# Out:
# doubly_linked_list(5 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.8s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 7.35ms avg
#   Render Layout: 24.63ms avg
#   Total Time: 32.50ms avg
#   Metrics saved to: spytial_perf_doubly_linked_list_5.json
# doubly_linked_list(10 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 8.07ms avg
#   Render Layout: 12.24ms avg
#   Total Time: 21.07ms avg
#   Metrics saved to: spytial_perf_doubly_linked_list_10.json
# doubly_linked_list(25 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 11.35ms avg
#   Render Layout: 99.35ms avg
#   Total Time: 112.19ms avg
#   Metrics saved to: spytial_perf_doubly_linked_list_25.json
# doubly_linked_list(50 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 25.50ms avg
#   Render Layout: 257.38ms avg
#   Total Time: 285.64ms avg
#   Metrics saved to: spytial_perf_doubly_linked_list_50.json

# %% [markdown]
# # Circular Doubly Linked List with Sentinel

# %%
VIEW = "CYCLIC"  # Change to "LINEAR" for linear layout,as in CLRS Figure 10.4

@attribute(selector='CircularNode', field='data')
@atomColor(selector='{x : CircularNode | x.data in NoneType}', value='black')
@hideAtom(selector="NoneType + int")
@apply_if(
    VIEW=="CYCLIC",
cyclic(selector='next & (CircularNode->CircularNode)', direction='clockwise')
)
@apply_if(
    VIEW=="LINEAR",
orientation(selector='next & (CircularNode -> (CircularNode - NoneType.~data))', directions=['directlyRight'])
)
class CircularNode:
    def __init__(self, data, next_node=None, prev_node=None):
        self.data = data
        self.next = next_node
        self.prev = prev_node


def buildCircularDoublyLinkedList(elements):
    """
    Build a circular doubly linked list with a sentinel node.
    The sentinel acts as both head and tail (prev of first == sentinel, next of last == sentinel).
    """
    sentinel = CircularNode(data=None)
    sentinel.next = sentinel
    sentinel.prev = sentinel
    
    current = sentinel
    for element in elements:
        new_node = CircularNode(data=element)
        # Insert after current
        new_node.next = current.next
        new_node.prev = current
        current.next.prev = new_node
        current.next = new_node
        current = new_node
    
    return sentinel

# %% [markdown]
# ![cdd](img/circular-doubly-linked-list.png)

# %%
# Build CLRS Figure 10.4: insert 9, 16, 4, 1 (in that order)
sentinel = buildCircularDoublyLinkedList([9, 16, 4, 1])


diagram(sentinel)
# Out:
#                 <div style="border: 2px solid #007acc; border-radius: 8px; overflow: hidden;">
#                     <iframe
#                         src="data:text/html;base64,..."
#                         width="100%"
#                         height="450px"
#                         frameborder="0"
#                         style="display: block;">
#                     </iframe>
#                 </div>

# %% [markdown]
# ## Performance

# %%
if RUN_PERF:
    STRUCTURE = "circular_doubly_linked_list"
    for size in SIZES:
        elements = random.sample(range(1, 1000), size)
        cdll = buildCircularDoublyLinkedList(elements)
        
        print(f"{STRUCTURE}({size} nodes): Rendering with perf_iterations={PI}...")
        diagram(cdll, method="browser", perf_path=get_perf_path(STRUCTURE, size), perf_iterations=PI, headless=True)
else:
    print("Performance testing skipped. Set RUN_PERF = True to enable.")
# Out:
# circular_doubly_linked_list(5 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 8.70ms avg
#   Render Layout: 37.08ms avg
#   Total Time: 46.39ms avg
#   Metrics saved to: spytial_perf_circular_doubly_linked_list_5.json
# circular_doubly_linked_list(10 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 14.19ms avg
#   Render Layout: 50.10ms avg
#   Total Time: 65.12ms avg
#   Metrics saved to: spytial_perf_circular_doubly_linked_list_10.json
# circular_doubly_linked_list(25 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (10.0s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 51.48ms avg
#   Render Layout: 110.28ms avg
#   Total Time: 163.10ms avg
#   Metrics saved to: spytial_perf_circular_doubly_linked_list_25.json
# circular_doubly_linked_list(50 nodes): Rendering with perf_iterations=20...
# Running 20 iterations (timeout: 120s)...
#   Progress: 20/20 iterations (20.5s elapsed)
# ✓ Headless benchmark completed: 20 iterations
#   Generate Layout: 497.62ms avg
#   Render Layout: 70.13ms avg
#   Total Time: 570.31ms avg
#   Metrics saved to: spytial_perf_circular_doubly_linked_list_50.json
